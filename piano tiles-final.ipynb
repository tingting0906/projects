# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 加入行為鍊 ActionChain (在 WebDriver 中模擬滑鼠移動、點繫、拖曳、按右鍵出現選單，以及鍵盤輸入文字、按下鍵盤上的按鈕等)
from selenium.webdriver.common.action_chains import ActionChains

# 加入鍵盤功能 (例如 Ctrl、Alt 等)
from selenium.webdriver.common.keys import Keys

# 強制等待 (執行期間休息一下)
from time import sleep

import pyautogui
from time import sleep, time
import keyboard, mouse
from IPython.display import clear_output

# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消通知

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options,
    service = Service(ChromeDriverManager().install())
)

# %%
driver = webdriver.Chrome(
    options = my_options,
    service = Service(ChromeDriverManager().install())
)

# %%
'''
[1] Crazy Game - magic piano tiles
https://www.crazygames.com/game/magic-piano-tiles
'''

# 前往頁面
driver.get('https://www.crazygames.com/game/magic-piano-tiles')

# 建立行為鍊
ac = ActionChains(driver)

ac.move_by_offset(565, 434)
ac.click()

ac.pause(10)

# 移到指定座標 (從 0,0 開始)
ac.move_by_offset(0, -114)

# 點擊一下
ac.click()

# 暫停一下
ac.pause(10)

# 執行
ac.perform()

listPoint = [
    [700, 550],
    [815, 550],
    [915, 550],
    [1015, 550],
]

#pyautogui.PAUSE = 0.005



# 點擊
def click():
#    for i in range(4):
        

        coord0 = pyautogui.pixel (listPoint[0][0], listPoint[0][1])
        coord1 = pyautogui.pixel (listPoint[1][0], listPoint[1][1])
        coord2 = pyautogui.pixel (listPoint[2][0], listPoint[2][1])
        coord3 = pyautogui.pixel (listPoint[3][0], listPoint[3][1])

        if coord0[0] == 0 and coord0[1] == 0: # 若 R = 0, G = 0
            pyautogui.click( listPoint[0][0], listPoint[0][1] , clicks =2) 
        if coord1[0] == 0 and coord1[1] == 0: # 若 R = 0, G = 0
            pyautogui.click( listPoint[1][0], listPoint[1][1] , clicks =2) 
        if coord2[0] == 0 and coord2[1] == 0: # 若 R = 0, G = 0
            pyautogui.click( listPoint[2][0], listPoint[2][1] , clicks =2) 
        elif coord3[0] == 0 and coord3[1] == 0: # 若 R = 0, G = 0
            pyautogui.click( listPoint[3][0], listPoint[3][1] , clicks =2 ) 
    
       
#         if coord0[0] == 0 and coord0[1] == 0: # 若 R = 0, G = 0
#             pyautogui.click( listPoint[0][0], listPoint[0][1] ) 
#         if coord1[0] == 0 and coord1[1] == 0: # 若 R = 0, G = 0
#             pyautogui.click( listPoint[1][0], listPoint[1][1] ) 
#         if coord2[0] == 0 and coord2[1] == 0: # 若 R = 0, G = 0
#             pyautogui.click( listPoint[2][0], listPoint[2][1] ) 
#         elif coord3[0] == 0 and coord3[1] == 0: # 若 R = 0, G = 0
#             pyautogui.click( listPoint[3][0], listPoint[3][1] ) 
            
'''
主程式區域
'''
if __name__ == "__main__":
    while True:
        # 當我們按下 ctrl 鍵時，自動點擊，按下 alt 則結束迴圈
        if keyboard.is_pressed('a'):
            click()
        elif keyboard.is_pressed('s'):
            break
